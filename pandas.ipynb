# %%
import pandas as pd
print("HELLO pandas")
p=pd.read_csv('modelling.csv')
p.tail(2)

# %%
df1=pd.DataFrame({'A':['A0','A1'],'B':['B0','B1']})
df2=pd.DataFrame({'B':['B0','B1'],'D':['D0','D1']})
merge_df=pd.merge(df1,df2,on='B',how='left')
print(merge_df)
# Out:
#     A   B   D
# 0  A0  B0  D0
# 1  A1  B1  D1

# %%
# Basic Pandas Operations
# p.info()
# p.describe()
# p.T
# p.columns
# p.sort_values('id')
# p['name'].sort_values()
# p['balances']=1000
# p
# p[3:6]

# %%
s=pd.Series(list('abcdef'),index=[49,48,47,0,1,2])
print(s)
# s.loc[0]
# s.iloc[0]
# Out:
# 49    a
# 48    b
# 47    c
# 0     d
# 1     e
# 2     f
# dtype: str
